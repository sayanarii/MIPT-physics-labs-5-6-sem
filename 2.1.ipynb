# %%
import matplotlib.pyplot as plt
import numpy as np
from math import sqrt
from math import fabs
# %matplotlib inline

# %%
# Ниже реализованы функции, которые считают погрешности для коэффициентов k и с, 
# найденных с помощью метода наименьших квадратов (y = kx + c)
# rmse означает root mean square error
def get_rmse_k(x, y, k, n):
    return  sqrt(fabs(((np.mean(y ** 2) - ((np.mean(y)) ** 2)) /
                 ((np.mean(x ** 2) - 
                   ((np.mean(x)) ** 2)))) - (k ** 2))) / sqrt(n)

def get_rmse_c(x, y, sigma_k, n):
    return sigma_k * sqrt(np.mean(x ** 2) - ((np.mean(x)) ** 2))

# %% [markdown]
# **Измерения на первой установке для измерения скорости звука при помощи раздвижной трубы**

# %% [markdown]
# **Экспериментальные данные:**

# %%
number_of_resonanse = np.array([0, 1, 2, 3, 4])
number_of_resonanse_ = np.array([0, 1, 2, 3, 4, 5])
# длина трубы записана в метрах
delta_L_f1 = np.array([0.700, 0.755, 0.809, 0.864, 0.918])
delta_L_f2 = np.array([0.700, 0.752, 0.801, 0.852, 0.902])
delta_L_f3 = np.array([0.700, 0.748, 0.796, 0.843, 0.890])
delta_L_f4 = np.array([0.700, 0.746, 0.790, 0.834, 0.8780, 0.921])
delta_L_f5 = np.array([0.700, 0.743, 0.785, 0.826, 0.868, 0.909])

# %% [markdown]
# **Измерения для $f_{1} = 3199$ Гц**

# %%
# Функция, которая высчитывает коэффициенты аппроксимирующей прямой:
#numpy.polyfit(x, y, deg, rcond=None, full=False, w=None, cov=False)
#Least squares polynomial fit. 
#Fit a polynomial p(x) = p[0] * x**deg + ... + p[deg] of degree deg to points (x, y).
#Returns a vector of coefficients p that minimises the squared error.

fig = plt.figure(figsize=(14, 9))
ax = fig.gca()
ax.set_xticks(np.arange(0, 5, 0.05), minor=True) # это для мелких делений по оси ОХ
ax.set_yticks(np.arange(0, 1, 0.005), minor=True) # аналогично для OY
ax.grid(which='minor', alpha=0.4, linestyle='-')

mnk_coef_f1 = np.polyfit(number_of_resonanse, delta_L_f1, 1) # считаем коэфф-ты аппроксимирующей прямой
xp = np.linspace(0, 5, 100)
p = np.poly1d(mnk_coef_f1) # создаем полином с коэффициентами (убывающими по степени) из массива mnk_coef_f1
_ = plt.plot(number_of_resonanse, delta_L_f1, '.', xp, p(xp), '-') # рисуем точки и аппроксимирующую прямую
plt.xlabel('$N$', horizontalalignment='right', x = 1, size = 15)
h = plt.ylabel('$L_{f1}, м$', verticalalignment='top', 
               horizontalalignment='right', y = 1, size = 15)
h.set_rotation(0)
plt.title('$L_{f1} (N)$', size = 17)
plt.grid()
plt.scatter(number_of_resonanse, delta_L_f1, color = 'red')


plt.show()

# %% [markdown]
# **Погрешности для $f_{1}$**

# %%
mnk_coef_f1
# Out:
# array([ 0.0545,  0.7002])

# %%
sigma_k = get_rmse_k(number_of_resonanse, delta_L_f1, mnk_coef_f1[0], 5)
sigma_c = get_rmse_c(number_of_resonanse, delta_L_f1, sigma_k, 5)

# %%
sigma_k, sigma_c
# Out:
# (7.745966691048122e-05, 0.000109544511481705)

# %% [markdown]
# **Измерения для $f_{2} = 3459$ Гц**

# %%
fig = plt.figure(figsize=(14, 9))
ax = fig.gca()
ax.set_xticks(np.arange(0, 5, 0.05), minor=True)
ax.set_yticks(np.arange(0, 1, 0.005), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

mnk_coef_f2 = np.polyfit(number_of_resonanse, delta_L_f2, 1)
xp = np.linspace(0, 5, 100)
p = np.poly1d(mnk_coef_f2) # создаем полином с коэффициентами (убывающими по степени) из массива mnk
_ = plt.plot(number_of_resonanse, delta_L_f2, '.', xp, p(xp), '-')
plt.xlabel('$N$', horizontalalignment='right', x = 1, size = 15)
h = plt.ylabel('$L_{f2}, м$', verticalalignment='top', horizontalalignment='right', y = 1, size = 15)
h.set_rotation(0)
plt.title('$L_{f2} (N)$', size = 17)
plt.grid()
plt.scatter(number_of_resonanse, delta_L_f2, color = 'red')


plt.show()

# %% [markdown]
# **Погрешности для $f_{2}$**

# %%
mnk_coef_f2
# Out:
# array([ 0.0504,  0.7006])

# %%
sigma_k = get_rmse_k(number_of_resonanse, delta_L_f2, mnk_coef_f2[0], 5)
sigma_c = get_rmse_c(number_of_resonanse, delta_L_f2, sigma_k, 5)

# %%
sigma_k, sigma_c
# Out:
# (0.00017888543828575883, 0.00025298221293477546)

# %% [markdown]
# **Измерения для $f_{3} = 3695$ Гц**

# %%
fig = plt.figure(figsize=(14, 9))
ax = fig.gca()
ax.set_xticks(np.arange(0, 5, 0.05), minor=True)
ax.set_yticks(np.arange(0, 1, 0.005), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

mnk_coef_f3 = np.polyfit(number_of_resonanse, delta_L_f3, 1)
xp = np.linspace(0, 5, 100)
p = np.poly1d(mnk_coef_f3) # создаем полином с коэффициентами (убывающими по степени) из массива mnk
_ = plt.plot(number_of_resonanse, delta_L_f3, '.', xp, p(xp), '-')
plt.xlabel('$N$', horizontalalignment='right', x = 1, size = 15)
h = plt.ylabel('$L_{f3}, м$', verticalalignment='top', horizontalalignment='right', y = 1, size = 15)
h.set_rotation(0)
plt.title('$L_{f3} (N)$', size = 17)
plt.grid()
plt.scatter(number_of_resonanse, delta_L_f3, color = 'red')


plt.show()

# %% [markdown]
# **Погрешности для $f_{3}$**

# %%
mnk_coef_f3
# Out:
# array([ 0.0475,  0.7004])

# %%
sigma_k = get_rmse_k(number_of_resonanse, delta_L_f3, mnk_coef_f3[0], 5)
sigma_c = get_rmse_c(number_of_resonanse, delta_L_f3, sigma_k, 5)

# %%
sigma_k, sigma_c
# Out:
# (0.00011832159569499495, 0.00016733200535348788)

# %% [markdown]
# ** Измерения для $f_{4} = 3945$ Гц **

# %%
fig = plt.figure(figsize=(14, 9))
ax = fig.gca()
ax.set_xticks(np.arange(0, 5, 0.05), minor=True)
ax.set_yticks(np.arange(0, 1, 0.005), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

mnk_coef_f4 = np.polyfit(number_of_resonanse_, delta_L_f4, 1)
xp = np.linspace(0, 5, 100)
p = np.poly1d(mnk_coef_f4) # создаем полином с коэффициентами (убывающими по степени) из массива mnk
_ = plt.plot(number_of_resonanse_, delta_L_f4, '.', xp, p(xp), '-')
plt.xlabel('$N$', horizontalalignment='right', x = 1, size = 15)
h = plt.ylabel('$L_{f4}, м$', verticalalignment='top', horizontalalignment='right', y = 1, size = 15)
h.set_rotation(0)
plt.title('$L_{f4} (N)$', size = 17)
plt.grid()
plt.scatter(number_of_resonanse_, delta_L_f4, color = 'red')
plt.show()

# %% [markdown]
# **Погрешности для $f_{4}$**

# %%
mnk_coef_f4
# Out:
# array([ 0.04414286,  0.70114286])

# %%
sigma_k = get_rmse_k(number_of_resonanse, delta_L_f4, mnk_coef_f4[0], 6)
sigma_c = get_rmse_c(number_of_resonanse, delta_L_f4, sigma_k, 6)

# %%
sigma_k, sigma_c
# Out:
# (0.012202229964222634, 0.017256559106599016)

# %% [markdown]
# ** Измерения для $f_{5} = 4190$ Гц**

# %%
fig = plt.figure(figsize=(14, 9))
ax = fig.gca()
ax.set_xticks(np.arange(0, 5, 0.05), minor=True)
ax.set_yticks(np.arange(0, 1, 0.005), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

mnk_coef_f5 = np.polyfit(number_of_resonanse_, delta_L_f5, 1)
xp = np.linspace(0, 5, 100)
p = np.poly1d(mnk_coef_f5) # создаем полином с коэффициентами (убывающими по степени) из массива mnk
_ = plt.plot(number_of_resonanse_, delta_L_f5, '.', xp, p(xp), '-')
plt.xlabel('$N$', horizontalalignment='right', x = 1, size = 15)
h = plt.ylabel('$L_{f5}, м$', verticalalignment='top', horizontalalignment='right', y = 1, size = 15)
h.set_rotation(0)
plt.title('$L_{f5} (N)$', size = 17)
plt.grid()
plt.scatter(number_of_resonanse_, delta_L_f5, color = 'red')
plt.show()

# %% [markdown]
# **Погрешности для $f_{5}$**

# %%
mnk_coef_f5
# Out:
# array([ 0.04174286,  0.70080952])

# %%
sigma_k = get_rmse_k(number_of_resonanse, delta_L_f5, mnk_coef_f5[0], 6)
sigma_c = get_rmse_c(number_of_resonanse, delta_L_f5, sigma_k, 6)

# %%
sigma_k, sigma_c
# Out:
# (0.011538125126886468, 0.016317373038800632)

# %% [markdown]
# Просто выписанные для удобства все вычисленные нами ранее коэффициенты:

# %%
mnk_coef_f1
# Out:
# array([ 0.0545,  0.7002])

# %%
mnk_coef_f2
# Out:
# array([ 0.0504,  0.7006])

# %%
mnk_coef_f3
# Out:
# array([ 0.0475,  0.7004])

# %%
mnk_coef_f4
# Out:
# array([ 0.04414286,  0.70114286])

# %%
mnk_coef_f5
# Out:
# array([ 0.04174286,  0.70080952])

# %% [markdown]
# Так как $L = L_{0} + \frac{1}{2}\lambda n$ :

# %%
lambda_half = np.array([0.0545, 0.0504, 0.0475, 0.0441, 0.0417])
lambda_ = 2 * lambda_half
frequencies = np.array([3199, 3459, 3695, 3945, 4190])
inversed_frequencies = 1 / frequencies

# %%
fig = plt.figure(figsize=(14, 9))
ax = fig.gca()
ax.set_xticks(np.arange(0.00023, 0.00032, 0.000001), minor=True)
ax.set_yticks(np.arange(0.080, 0.110, 0.0005), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

mnk_coef = np.polyfit(inversed_frequencies, lambda_, 1)
xp = np.linspace(0.00023, 0.00032, 100)
p = np.poly1d(mnk_coef)
_ = plt.plot(inversed_frequencies, lambda_, '.', xp, p(xp), '-')
plt.xlabel('$\\frac{1}{f}, с$', horizontalalignment='right', x = 1, size = 15)
h = plt.ylabel('$\lambda, м$',verticalalignment='top', horizontalalignment='right', y = 1, size = 15)
h.set_rotation(0)
plt.title('$\lambda (\\frac{1}{f})$', size = 17)
plt.grid()
plt.scatter(inversed_frequencies, lambda_, color = 'red')
plt.show()

# %% [markdown]
# Так как $\lambda = v\frac{1}{f}$, то мы можем получить $v$ как угловой коэффициент наклона графика выше:

# %%
v = mnk_coef[0] # значение скорости звука, вычисленное с помощью мнк
v
# Out:
# 347.49514334718469

# %% [markdown]
# ** Погрешности для $v$**

# %%
sigma_k = get_rmse_k(inversed_frequencies, lambda_, mnk_coef[0], 5)
sigma_c = get_rmse_c(inversed_frequencies, lambda_, sigma_k, 5)

# %%
sigma_k, sigma_c
# Out:
# (4.769857818413764, 0.00012424661614225053)

# %% [markdown]
# **Измерения на второй установке для изучения зависимости скорости звука от температуры**

# %% [markdown]
# **Экспериментальные данные:**

# %%
L = 0.7 #в метрах
sigma_L = 0.001
R_const = 8.31 # универсальная газовая постоянная
mu_CO2 = 44.01 * 10 **(-3) # молярная масса углекислого газа в кг/моль
temperatue_celsius = np.array([21, 30, 40, 50, 60])
temperature_kelvin = temperatue_celsius + 273.15
number_of_resonanse = np.array([1, 2, 3, 4, 5, 6])
# частота записана в Герцах
resonant_frequency_T1 = np.array([263.0, 502.9, 743.1, 989.5, 1231.6, 1469.2])
resonant_frequency_T2 = np.array([268.1, 508.6, 750.7, 1007, 1247.3, 1499.2])
resonant_frequency_T3 = np.array([273.7, 516.8, 765.5, 1012.1, 1280, 1525])
resonant_frequency_T4 = np.array([274.4, 524.2, 775, 1035, 1285, 1531])
resonant_frequency_T5 = np.array([279.1, 529.7, 780.2, 1053.3, 1313.1, 1565])

# %% [markdown]
# **График для $T_{1}$:**

# %%
fig = plt.figure(figsize=(14, 9))
ax = fig.gca()
ax.set_xticks(np.arange(0, 7, 0.05), minor=True)
ax.set_yticks(np.arange(0, 1750, 20), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

mnk_coef_T1 = np.polyfit(number_of_resonanse, resonant_frequency_T1, 1)
xp = np.linspace(0, 7, 100)
p = np.poly1d(mnk_coef_T1)
_ = plt.plot(number_of_resonanse, resonant_frequency_T1, '.', xp, p(xp), '-')
plt.xlabel('$N$', horizontalalignment='right', x = 1, size = 15)
h = plt.ylabel('$f, Гц$', verticalalignment='top', horizontalalignment='right', y = 1, size = 15)
h.set_rotation(0)
plt.title('$f_{T1}(N)$', size = 17)
plt.grid()
plt.scatter(number_of_resonanse, resonant_frequency_T1, color = 'red')
plt.show()

# %% [markdown]
# **Вычисления и погрешности для $T_{1}$**

# %%
mnk_coef_T1
# Out:
# array([ 241.81428571,   20.2       ])

# %%
sigma_k = get_rmse_k(number_of_resonanse, resonant_frequency_T1, mnk_coef_T1[0], 6)
sigma_c = get_rmse_c(number_of_resonanse, resonant_frequency_T1, sigma_k, 6)

# %%
sigma_k, sigma_c
# Out:
# (0.4519948226867015, 0.7719281157565447)

# %% [markdown]
# Так как $v$ = 2$Lk$, где $k$ -- это коэффициент, полученный с помощью мнк, то $\sigma_{v}$ = 2$L \sigma_{k}$ + $2k \sigma_{L}$

# %%
v = 2 * L * mnk_coef_T1[0]
v
# Out:
# 338.53999999999996

# %%
sigma_v = 2 * L * sigma_k + 2 * mnk_coef_T1[0] * sigma_L
sigma_v
# Out:
# 1.1164213231899534

# %% [markdown]
# **График для $T_{2}$:**

# %%
fig = plt.figure(figsize=(14, 9))
ax = fig.gca()
ax.set_xticks(np.arange(0, 7, 0.05), minor=True)
ax.set_yticks(np.arange(0, 1750, 20), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

mnk_coef_T2 = np.polyfit(number_of_resonanse, resonant_frequency_T2, 1)
xp = np.linspace(0, 7, 100)
p = np.poly1d(mnk_coef_T2)
_ = plt.plot(number_of_resonanse, resonant_frequency_T2, '.', xp, p(xp), '-')
plt.xlabel('$N$', horizontalalignment='right', x = 1, size = 15)
h = plt.ylabel('$f, Гц$', verticalalignment='top', horizontalalignment='right', y = 1, size = 15)
h.set_rotation(0)
plt.title('$f_{T2}(N)$', size = 17)
plt.grid()
plt.scatter(number_of_resonanse, resonant_frequency_T2, color = 'red')
plt.show()

# %% [markdown]
# **Вычисления и погрешности для $T_{2}$:**

# %%
mnk_coef_T2
# Out:
# array([ 246.51142857,   17.36      ])

# %%
sigma_k = get_rmse_k(number_of_resonanse, resonant_frequency_T2, mnk_coef_T2[0], 6)
sigma_c = get_rmse_c(number_of_resonanse, resonant_frequency_T2, sigma_k, 6)

# %%
sigma_k, sigma_c
# Out:
# (0.9096190426388814, 1.5534702576166537)

# %%
v = 2 * L * mnk_coef_T2[0]
v
# Out:
# 345.11599999999993

# %%
sigma_v = 2 * L * sigma_k + 2 * mnk_coef_T2[0] * sigma_L
sigma_v
# Out:
# 1.7664895168372909

# %% [markdown]
# **График для $T_{3}$:**

# %%
fig = plt.figure(figsize=(14, 9))
ax = fig.gca()
ax.set_xticks(np.arange(0, 7, 0.05), minor=True)
ax.set_yticks(np.arange(0, 1750, 20), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

mnk_coef_T3 = np.polyfit(number_of_resonanse, resonant_frequency_T3, 1)
xp = np.linspace(0, 7, 100)
p = np.poly1d(mnk_coef_T3)
_ = plt.plot(number_of_resonanse, resonant_frequency_T3, '.', xp, p(xp), '-')
plt.xlabel('$N$', horizontalalignment='right', x = 1, size = 15)
h = plt.ylabel('$f, Гц$', verticalalignment='top', horizontalalignment='right', y = 1, size = 15)
h.set_rotation(0)
plt.title('$f_{T3}(N)$', size = 17)
plt.grid()
plt.scatter(number_of_resonanse, resonant_frequency_T3, color = 'red')
plt.show()

# %% [markdown]
# **Вычисления и погрешности для $T_{3}$:**

# %%
mnk_coef_T3
# Out:
# array([ 251.22      ,   16.24666667])

# %%
sigma_k = get_rmse_k(number_of_resonanse, resonant_frequency_T3, mnk_coef_T3[0], 6)
sigma_c = get_rmse_c(number_of_resonanse, resonant_frequency_T3, sigma_k, 6)

# %%
sigma_k, sigma_c
# Out:
# (1.3936636655544967, 2.3801338275406185)

# %%
v = 2 * L * mnk_coef_T3[0]
v
# Out:
# 351.70800000000003

# %%
sigma_v = 2 * L * sigma_k + 2 * mnk_coef_T3[0] * sigma_L
sigma_v
# Out:
# 2.4535691317762955

# %% [markdown]
# **График для $T_{4}$:**

# %%
fig = plt.figure(figsize=(14, 9))
ax = fig.gca()
ax.set_xticks(np.arange(0, 7, 0.05), minor=True)
ax.set_yticks(np.arange(0, 1750, 20), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

mnk_coef_T4 = np.polyfit(number_of_resonanse, resonant_frequency_T4, 1)
xp = np.linspace(0, 7, 100)
p = np.poly1d(mnk_coef_T4)
_ = plt.plot(number_of_resonanse, resonant_frequency_T4, '.', xp, p(xp), '-')
plt.xlabel('$N$', horizontalalignment='right', x = 1, size = 15)
h = plt.ylabel('$f, Гц$', verticalalignment='top', horizontalalignment='right', y = 1, size = 15)
h.set_rotation(0)
plt.title('$f_{T4}(N)$', size = 17)
plt.grid()
plt.scatter(number_of_resonanse, resonant_frequency_T4, color = 'red')
plt.show()

# %% [markdown]
# **Вычисления и погрешности для $T_{4}$:**

# %%
mnk_coef_T4
# Out:
# array([ 252.15428571,   21.56      ])

# %%
sigma_k = get_rmse_k(number_of_resonanse, resonant_frequency_T4, mnk_coef_T4[0], 6)
sigma_c = get_rmse_c(number_of_resonanse, resonant_frequency_T4, sigma_k, 6)

# %%
sigma_k, sigma_c
# Out:
# (0.7232428859693608, 1.235172374059762)

# %%
v = 2 * L * mnk_coef_T4[0]
v
# Out:
# 353.01600000000008

# %%
sigma_v = 2 * L * sigma_k + 2 * mnk_coef_T4[0] * sigma_L
sigma_v
# Out:
# 1.5168486117856765

# %% [markdown]
# **График для $T_{5}$:**

# %%
fig = plt.figure(figsize=(14, 9))
ax = fig.gca()
ax.set_xticks(np.arange(0, 7, 0.05), minor=True)
ax.set_yticks(np.arange(0, 1750, 20), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

mnk_coef_T5 = np.polyfit(number_of_resonanse, resonant_frequency_T5, 1)
xp = np.linspace(0, 7, 100)
p = np.poly1d(mnk_coef_T5)
_ = plt.plot(number_of_resonanse, resonant_frequency_T5, '.', xp, p(xp), '-')
plt.xlabel('$N$', horizontalalignment='right', x = 1, size = 15)
h = plt.ylabel('$f, Гц$', verticalalignment='top', horizontalalignment='right', y = 1, size = 15)
h.set_rotation(0)
plt.title('$f_{T5}(N)$', size = 17)
plt.grid()
plt.scatter(number_of_resonanse, resonant_frequency_T5, color = 'red')
plt.show()

# %% [markdown]
# **Вычисления и погрешности для $T_{5}$:**

# %%
mnk_coef_T5
# Out:
# array([ 258.65142857,   14.78666667])

# %%
sigma_k = get_rmse_k(number_of_resonanse, resonant_frequency_T5, mnk_coef_T5[0], 6)
sigma_c = get_rmse_c(number_of_resonanse, resonant_frequency_T5, sigma_k, 6)

# %%
sigma_k, sigma_c
# Out:
# (1.3543125039255812, 2.312928924908149)

# %%
v = 2 * L * mnk_coef_T5[0]
v
# Out:
# 362.11199999999991

# %%
sigma_v = 2 * L * sigma_k + 2 * mnk_coef_T5[0] * sigma_L
sigma_v
# Out:
# 2.4133403626386709

# %% [markdown]
# Просто еще раз выписанные для удобства вычисленные нами ранее коэффициенты для второй уставноки:

# %%
mnk_coef_T1
# Out:
# array([ 241.81428571,   20.2       ])

# %%
mnk_coef_T2
# Out:
# array([ 246.51142857,   17.36      ])

# %%
mnk_coef_T3
# Out:
# array([ 251.22      ,   16.24666667])

# %%
mnk_coef_T4
# Out:
# array([ 252.15428571,   21.56      ])

# %%
mnk_coef_T5
# Out:
# array([ 258.65142857,   14.78666667])

# %% [markdown]
# Массивчик с вычисленными скоростями для каждой конкретной $T$

# %%
array_of_v = np.array([338.539, 345.116, 351.708, 353.016, 362.112])
array_of_v_2 = array_of_v * array_of_v # скорости, возведенные в квадрат

# %%
np.mean(array_of_v)
# Out:
# 350.09820000000002

# %%
array_of_v_2
# Out:
# array([ 114608.654521,  119105.053456,  123698.517264,  124620.296256,
#         131125.100544])

# %% [markdown]
# Так как $v^{2} = \gamma \frac{RT}{\mu}$, то мы можем вычислить коэффициент $k = \frac {\gamma R}{\mu}$, как коэффициент наклона графика $v^{2}(T)$, а затем посчитать саму $\gamma$ и погрешности для нее.

# %%
fig = plt.figure(figsize=(14, 9))
ax = fig.gca()
ax.set_xticks(np.arange(290, 340, 0.5), minor=True)
ax.set_yticks(np.arange(110000, 133000, 500), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

mnk_coef = np.polyfit(temperature_kelvin, array_of_v_2, 1)
xp = np.linspace(285, 340, 100)
p = np.poly1d(mnk_coef)
_ = plt.plot(temperature_kelvin, array_of_v_2, '.', xp, p(xp), '-')
plt.xlabel('$T, K$', horizontalalignment='right', x = 1, size = 15)
h = plt.ylabel('$v^{2},\\frac{м^{2}}{c^{2}}$', verticalalignment='top', horizontalalignment='right', y = 1, size = 15)
h.set_rotation(0)
plt.title('$v^{2}(T)$', size = 17)
plt.grid()
plt.scatter(temperature_kelvin, array_of_v_2, color = 'red')
plt.show()

# %%
mnk_coef
# Out:
# array([ 392.85853307, -470.69692901])

# %%
mu_vozduh = 29 * 10**(-3)

# %% [markdown]
# Вычислим $\gamma$:

# %%
gamma =  mnk_coef[0] / R_const * mu_vozduh
gamma # значение адиабаты для воздуха
# Out:
# 1.370986457160547

# %% [markdown]
# Погрешности:

# %%
sigma_k = get_rmse_k(temperature_kelvin, array_of_v_2, mnk_coef[0], 5)
sigma_c = get_rmse_c(temperature_kelvin, array_of_v_2, sigma_k, 5)

# %%
sigma_k, sigma_c # погрешность для коэффициентов из мнк
# Out:
# (34.594045178786885, 479.54883833200876)

# %%
sigma_gamma = sigma_k / R_const * mu_vozduh

# %%
sigma_gamma # погрешность для гаммы
# Out:
# 0.12072530808481584
