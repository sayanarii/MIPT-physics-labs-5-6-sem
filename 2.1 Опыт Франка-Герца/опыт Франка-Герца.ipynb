# %%
import numpy as np

# %%
# 4V
U = np.array([5.0, 10.11, 15.05, 20.61, 25.18, 30.20, 34.95, 40.40, 45.20, 50.05, 55.28, 60.30, 62.20, 64.20, 65.95, 67.70, 70.60, 40.80, 38.90, 36.08, 35.36, 27.90, 28.95, 25.96, 23.04, 21.86, 20.05, 18.70, 16.6, 14.35]) #вольт

# %%
U       I
40.80 75.50
38.90 79
36.08 78
35.36 76

27.90 53
28.95 56.5
25.96 48
23.04 53.3
21.86 53
20.05 51.7
18.70 49.7
16.6 44.5
14.35 39
# Out:
#   File "<ipython-input-41-dd06d5a3e4c4>", line 1
#     U       I
#             ^
# SyntaxError: invalid syntax

# %%
I = np.array([12, 27.5, 41, 52, 44.5, 60, 74.5, 76, 73, 77, 85, 91, 90.2, 93, 94, 94.5, 96, 70.50, 79, 78, 76, 53, 56.5, 48, 53.3, 53, 51.7, 49.7, 44.5, 39]) #мА

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.gca()
ax.set_xticks(np.arange(0, 75, 0.5), minor=True) # это для мелких делений по оси ОХ
ax.set_yticks(np.arange(0, 100, 1), minor=True) # аналогично для OY
ax.grid(which='minor', alpha=0.4, linestyle='-')


plt.title('Задерживающее напряжение: $4$В', size = 17)
plt.grid(ls=':')

plt.vlines(23.04, 0, 100, color='red');
plt.vlines(38.04, 0, 100, color='red');
plt.vlines(60, 0, 100, color='red');

plt.ylim(ymin=0, ymax=100)

w
# Out:
# No handles with labels found to put in legend.

# %%
U_6 = np.array([2.52, 4.00, 5.32, 6.63, 7.86, 8.96, 10.17, 11.47, 12.97, 14.19, 15.53, 16.68, 17.71, 18.72, 20.26, 22.08, 24.30, 26.30, 27.30, 30.6, 33.82, 36.18, 39.20, 41.52, 44.86, 46.68, 48.84, 51.04, 53.18, 57.14, 58.70, 59.90, 62.90, 65.95, 68.89, 72.34, 24.22, 28.13])
I_6 = np.array([1, 4.00, 7.1, 10.8, 14.5, 18.0, 22, 25.5, 30, 33.3, 37, 40.2, 42.6, 45.0, 47.7, 49.3, 48.5, 30.3, 33.0, 44.5, 55.8, 61.8, 63.5, 60.5, 56.2, 55.3, 56, 58, 60.5, 65.5, 67.5, 68.5, 70, 71, 71.3, 72, 50.5, 37.7])

# %%
24.22 50.5
28.13 37.7
# Out:
#   File "<ipython-input-96-7550f35967f2>", line 1
#     24.22 50.5
#              ^
# SyntaxError: invalid syntax

# %%
U_6.shape, I_6.shape
# Out:
# ((38,), (38,))

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.gca()
ax.set_xticks(np.arange(0, 75, 0.5), minor=True) # это для мелких делений по оси ОХ
ax.set_yticks(np.arange(0, 100, 1), minor=True) # аналогично для OY
ax.grid(which='minor', alpha=0.4, linestyle='-')
# ax.annotate(s='24.04',xy=(24.04, 0), textcoords=(2, 1))
plt.grid(ls=':')

plt.title('Задерживающее напряжение: $6$В', size = 17)
plt.grid(ls=':')

plt.vlines(24.04, 0, 100, color='red');
plt.vlines(39.04, 0, 100, color='red');
plt.vlines(61.5, 0, 100, color='red');

plt.ylim(ymin=0, ymax=100)


plt.xlabel('U, В', fontsize=15); 
plt.ylabel('I, мА', fontsize=15)

plt.scatter(U_6, I_6, color='blue')
# plt.plot(P, time_p_merge_sort, '.-', label = 'mergesort time', color = 'blue')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
U_8 = np.array([5.23 , 7.69, 10.04, 12.53, 15.3, 17.05, 18.86, 20, 21.67, 23.0, 24.48, 25.38, 26.66, 27.40, 28.13, 29.45, 30.50, 32.74, 33.50, 34.96, 36.10, 37.10, 38.25, 39.40, 41.40, 43.28, 44.60, 46.65, 48.10, 49.40, 50.57, 51.60, 53.29, 54.50, 55.35, 56.70, 58.20, 59.80, 61.30, 63.70, 65.40, 66.92, 69.03, 72.05])

# %%
I_8 = np.array([2.1, 8.5, 16, 24, 32.5, 38, 42.5, 45, 48, 49, 48.2, 41, 21, 21, 22, 26, 30.5, 40, 42.5, 48, 51.3, 52.5, 54, 54, 51.8, 49.5, 47.2, 44.2, 43, 42.2, 42.5, 43, 44.5, 45.8, 47, 48.5, 50, 51.5, 52.5, 53, 53, 52.9, 52.5, 52])

# %%
fig=plt.figure(figsize=(14, 8))

plt.grid(ls=':')
ax = fig.gca()
ax.set_xticks(np.arange(0, 75, 0.5), minor=True) # это для мелких делений по оси ОХ
ax.set_yticks(np.arange(0, 100, 1), minor=True) # аналогично для OY
ax.grid(which='minor', alpha=0.4, linestyle='-')
plt.grid(ls=':')

plt.title('Задерживающее напряжение: $8$В', size = 17)
plt.grid(ls=':')

plt.vlines(23.04, 0, 100, color='red');
plt.vlines(38.5, 0, 100, color='red');
plt.vlines(62.5, 0, 100, color='red');

plt.ylim(ymin=0, ymax=100)

plt.xlabel('U, В', fontsize=15); 
plt.ylabel('I, мА', fontsize=15)



plt.scatter(U_8, I_8, color='blue')
# plt.plot(P, time_p_merge_sort, '.-', label = 'mergesort time', color = 'blue')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
E = np.array([15, 15, 15.46])
E_mean = np.mean(E)

# %%
sigma = np.sqrt(1/3 * np.sum((E - E_mean) ** 2)) /  np.sqrt(3)

# %%
sigma
# Out:
# 0.12519614240891822

# %%
E_mean
# Out:
# 15.153333333333334

# %%
13.6 * 0.75
# Out:
# 10.2

# %%
13.6 * 4
# Out:
# 54.4

# %%
0.75 * 54.4
# Out:
# 40.8

# %%
54.5 - 40.8
# Out:
# 13.700000000000003
